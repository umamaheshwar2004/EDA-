# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data=pd.read_csv("covid.csv")
data
# Out:
#         Direction  Year        Date    Weekday Country Commodity  \
# 0         Exports  2015  01/01/2015   Thursday     All       All
# 1         Exports  2015  02/01/2015     Friday     All       All
# 2         Exports  2015  03/01/2015   Saturday     All       All
# 3         Exports  2015  04/01/2015     Sunday     All       All
# 4         Exports  2015  05/01/2015     Monday     All       All
# ...           ...   ...         ...        ...     ...       ...
# 111433  Reimports  2021  11/12/2021   Saturday     All       All
# 111434  Reimports  2021  12/12/2021     Sunday     All       All
# 111435  Reimports  2021  13/12/2021     Monday     All       All
# 111436  Reimports  2021  14/12/2021    Tuesday     All       All
# 111437  Reimports  2021  15/12/2021  Wednesday     All       All
#
#        Transport_Mode Measure      Value  Cumulative
# 0                 All       $  104000000   104000000
# 1                 All       $   96000000   200000000
# ...

# %%
print(data.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111438 entries, 0 to 111437
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Direction       111438 non-null  object
#  1   Year            111438 non-null  int64
#  2   Date            111438 non-null  object
#  3   Weekday         111438 non-null  object
#  4   Country         111438 non-null  object
#  5   Commodity       111438 non-null  object
#  6   Transport_Mode  111438 non-null  object
#  7   Measure         111438 non-null  object
#  8   Value           111438 non-null  int64
#  9   Cumulative      111438 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 8.5+ MB
# None
#                 Year         Value    Cumulative
# count  111438.000000  1.114380e+05  1.114380e+05
# mean     2017.982430  2.905750e+07  5.174254e+09
# std         1.992352  5.267248e+07  9.765606e+09
# min      2015.000000  0.000000e+00  0.000000e+00
# ...

# %%
data.head()
# Out:
#   Direction  Year        Date   Weekday Country Commodity Transport_Mode  \
# 0   Exports  2015  01/01/2015  Thursday     All       All            All
# 1   Exports  2015  02/01/2015    Friday     All       All            All
# 2   Exports  2015  03/01/2015  Saturday     All       All            All
# 3   Exports  2015  04/01/2015    Sunday     All       All            All
# 4   Exports  2015  05/01/2015    Monday     All       All            All
#
#   Measure      Value  Cumulative
# 0       $  104000000   104000000
# 1       $   96000000   200000000
# 2       $   61000000   262000000
# 3       $   74000000   336000000
# 4       $  105000000   442000000

# %%
data.tail()
# Out:
#         Direction  Year        Date    Weekday Country Commodity  \
# 111433  Reimports  2021  11/12/2021   Saturday     All       All
# 111434  Reimports  2021  12/12/2021     Sunday     All       All
# 111435  Reimports  2021  13/12/2021     Monday     All       All
# 111436  Reimports  2021  14/12/2021    Tuesday     All       All
# 111437  Reimports  2021  15/12/2021  Wednesday     All       All
#
#        Transport_Mode Measure    Value  Cumulative
# 111433            All       $        0   165000000
# 111434            All       $        0   165000000
# 111435            All       $  2000000   166000000
# 111436            All       $  1000000   167000000
# 111437            All       $  1000000   168000000

# %%
s=data.drop(['Country','Commodity','Transport_Mode','Measure'],axis='columns',inplace=True)
data
# Out:
#         Direction  Year        Date    Weekday      Value  Cumulative
# 0         Exports  2015  01/01/2015   Thursday  104000000   104000000
# 1         Exports  2015  02/01/2015     Friday   96000000   200000000
# 2         Exports  2015  03/01/2015   Saturday   61000000   262000000
# 3         Exports  2015  04/01/2015     Sunday   74000000   336000000
# 4         Exports  2015  05/01/2015     Monday  105000000   442000000
# ...           ...   ...         ...        ...        ...         ...
# 111433  Reimports  2021  11/12/2021   Saturday          0   165000000
# 111434  Reimports  2021  12/12/2021     Sunday          0   165000000
# 111435  Reimports  2021  13/12/2021     Monday    2000000   166000000
# 111436  Reimports  2021  14/12/2021    Tuesday    1000000   167000000
# 111437  Reimports  2021  15/12/2021  Wednesday    1000000   168000000
#
# [111438 rows x 6 columns]

# %%
data.head()
# Out:
#   Direction  Year        Date   Weekday      Value  Cumulative
# 0   Exports  2015  01/01/2015  Thursday  104000000   104000000
# 1   Exports  2015  02/01/2015    Friday   96000000   200000000
# 2   Exports  2015  03/01/2015  Saturday   61000000   262000000
# 3   Exports  2015  04/01/2015    Sunday   74000000   336000000
# 4   Exports  2015  05/01/2015    Monday  105000000   442000000

# %%
data.isnull().sum()
# Out:
# Direction     0
# Year          0
# Date          0
# Weekday       0
# Value         0
# Cumulative    0
# dtype: int64

# %%
display(data[data['Value']>=50])
# Out:
#         Direction  Year        Date    Weekday      Value  Cumulative
# 0         Exports  2015  01/01/2015   Thursday  104000000   104000000
# 1         Exports  2015  02/01/2015     Friday   96000000   200000000
# 2         Exports  2015  03/01/2015   Saturday   61000000   262000000
# 3         Exports  2015  04/01/2015     Sunday   74000000   336000000
# 4         Exports  2015  05/01/2015     Monday  105000000   442000000
# ...           ...   ...         ...        ...        ...         ...
# 111430  Reimports  2021  08/12/2021  Wednesday    1000000   162000000
# 111432  Reimports  2021  10/12/2021     Friday    2000000   165000000
# 111435  Reimports  2021  13/12/2021     Monday    2000000   166000000
# 111436  Reimports  2021  14/12/2021    Tuesday    1000000   167000000
# 111437  Reimports  2021  15/12/2021  Wednesday    1000000   168000000
#
# [103679 rows x 6 columns]

# %%
display(data[data.Direction=='Exports'])
# Out:
#        Direction  Year        Date    Weekday      Value   Cumulative
# 0        Exports  2015  01/01/2015   Thursday  104000000    104000000
# 1        Exports  2015  02/01/2015     Friday   96000000    200000000
# 2        Exports  2015  03/01/2015   Saturday   61000000    262000000
# 3        Exports  2015  04/01/2015     Sunday   74000000    336000000
# 4        Exports  2015  05/01/2015     Monday  105000000    442000000
# ...          ...   ...         ...        ...        ...          ...
# 107251   Exports  2021  11/12/2021   Saturday   32000000  12427000000
# 107252   Exports  2021  12/12/2021     Sunday   34000000  12461000000
# 107253   Exports  2021  13/12/2021     Monday   40000000  12502000000
# 107254   Exports  2021  14/12/2021    Tuesday   33000000  12535000000
# 107255   Exports  2021  15/12/2021  Wednesday   52000000  12587000000
#
# [80973 rows x 6 columns]

# %%
Exports=data[data.Direction=='Exports']

# %%
plt.bar(Exports['Year'],Exports['Cumulative'])
plt.title('covid cases')
plt.ylabel('weekdays')
plt.gcf().set_size_inches(5,5)
plt.show()

# %%
data
# Out:
#         Direction  Year        Date    Weekday      Value  Cumulative
# 0         Exports  2015  01/01/2015   Thursday  104000000   104000000
# 1         Exports  2015  02/01/2015     Friday   96000000   200000000
# 2         Exports  2015  03/01/2015   Saturday   61000000   262000000
# 3         Exports  2015  04/01/2015     Sunday   74000000   336000000
# 4         Exports  2015  05/01/2015     Monday  105000000   442000000
# ...           ...   ...         ...        ...        ...         ...
# 111433  Reimports  2021  11/12/2021   Saturday          0   165000000
# 111434  Reimports  2021  12/12/2021     Sunday          0   165000000
# 111435  Reimports  2021  13/12/2021     Monday    2000000   166000000
# 111436  Reimports  2021  14/12/2021    Tuesday    1000000   167000000
# 111437  Reimports  2021  15/12/2021  Wednesday    1000000   168000000
#
# [111438 rows x 6 columns]

# %%
display(data['Weekday'].value_counts())
# Out:
# Weekday
# Friday       15959
# Tuesday      15934
# Monday       15931
# Sunday       15925
# Thursday     15919
# Wednesday    15897
# Saturday     15873
# Name: count, dtype: int64

# %%
# plt.bar(data['Weekday'],data['Cumulative'],color='#380282')
# plt.title("Weekday")
# plt.xlable("Cumulative")
# plt.gcf().set_size_inches(30,10)
# plt.show()

# %%
weekday=data["Weekday"].value_counts().head(7).values
Year=data["Weekday"].value_counts().head(7).index
plt.gcf().set_size_inches(20,11)
plt.pie(weekday,labels=Year,autopct="%1.1f%%",wedgeprops={'edgecolor':'black'},explode=[0,0,0,0,0,0,0])
plt.title('COVID CASES PERCENTAGE ')
plt.show()
